# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a293a63a97dc00a97973ba034d28ed77

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Buenaventura"
city_weather = requests.get(city_url)
city_weather
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -77.07, 'lat': 3.89},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10d'}],
#  'base': 'model',
#  'main': {'temp': 78.69,
#   'pressure': 1009,
#   'humidity': 93,
#   'temp_min': 78.69,
#   'temp_max': 78.69,
#   'sea_level': 1009,
#   'grnd_level': 1003},
#  'wind': {'speed': 4.56, 'deg': 226},
#  'rain': {'3h': 6.38},
#  'clouds': {'all': 100},
#  'dt': 1573418473,
#  'sys': {'country': 'CO', 'sunrise': 1573383213, 'sunset': 1573426255},
#  'timezone': -18000,
#  'id': 3688451,
#  'name': 'Buenaventura',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
#weather_response_df = pd.DataFrame(weather_response)
#weather_response_df.head(10)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
counter = 0
# Loop through all the cities in the list.
for city in cities:

    # Group cities in sets of 50 for logging purposes.
    #if it is raining, get the amount of rainfall in inches 
    #for the last three hours. If it is not raining, add 0 inches for the city
    counter += 1
    if (counter % 50 == 0):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    rain_3h=0
    snow_3h=0
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #city_description=city_weather["weather"]["description"]
        #snow_3h=city_weather["snow"]["3h"]
        #rain_3h=city_weather["rain"]["3h"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        #print(city_weather["weather"][0]["main"])
        #weather_main=city_weather["weather"]["main"]
       
        try:
            if city_weather["weather"][0]["main"] == "Rain":
                rain_3h=city_weather["rain"]["3h"]     
                #city_data.append({"Rain inches last 3 hrs":rain_3h})   
                #print("tttttttttttttttttttttttttttttttttt")
                #print(rain_3h)


                #city_data.append({"Rain inches last 3 hrs":rain_3h})   
            #Append the city information into city_data list.
        except:
            rain_3h=0   
            #city_data.append({"Rain inches last 3 hrs":rain_3h})
            
            
    
        try:
            if city_weather["weather"][0]["main"] == "Snow":
                snow_3h=city_weather["snow"]["3h"]     
                #city_data.append({"Rain inches last 3 hrs":rain_3h})   
                #print(snow_3h)
        except:
            snow_3h=0   
            #city_data.append({"Rain inches last 3 hrs":rain_3h})
            
   
            
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                          #"Current description": city_description,
                          "Rain inches (last 3 hrs)":rain_3h,
                          "Snow inches (last 3 hrs)":snow_3h
                          }) 

#rain_list = []
#if ... :
 #try rain_list.append(json_object['Rain']['3h']   
                      #except: rain_list.append(json_object['Rain']['1h']
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
len(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | padang
# Processing Record 3 of Set 1 | chuy
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | vallenar
# Processing Record 7 of Set 1 | jalu
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | nizwa
# Processing Record 10 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | awjilah
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | hervey bay
# Processing Record 20 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | portland
# Processing Record 23 of Set 1 | pavilosta
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | san buenaventura
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 1 | ormara
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | darhan
# Processing Record 37 of Set 1 | dutlwe
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | sembakung
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | port macquarie
# Processing Record 42 of Set 1 | ambon
# Processing Record 43 of Set 1 | omboue
# Processing Record 44 of Set 1 | buchanan
# Processing Record 45 of Set 1 | nome
# Processing Record 46 of Set 1 | tuatapere
# Processing Record 47 of Set 1 | port lincoln
# Processing Record 48 of Set 1 | coquimbo
# Processing Record 49 of Set 1 | hamilton
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | sistranda
# Processing Record 3 of Set 2 | lorengau
# Processing Record 4 of Set 2 | butaritari
# Processing Record 5 of Set 2 | corinto
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | moose factory
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | tumarbong
# Processing Record 10 of Set 2 | sorland
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | karratha
# Processing Record 14 of Set 2 | fortuna
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | beloha
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | malatya
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | christchurch
# Processing Record 21 of Set 2 | vao
# Processing Record 22 of Set 2 | leh
# Processing Record 23 of Set 2 | puerto escondido
# Processing Record 24 of Set 2 | hashtrud
# Processing Record 25 of Set 2 | alaca
# Processing Record 26 of Set 2 | inirida
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | lompoc
# Processing Record 31 of Set 2 | bac lieu
# City not found. Skipping...
# Processing Record 32 of Set 2 | maralal
# Processing Record 33 of Set 2 | noumea
# Processing Record 34 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 2 | ajdabiya
# Processing Record 36 of Set 2 | magdeburg
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | damghan
# Processing Record 39 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | sisimiut
# Processing Record 42 of Set 2 | tual
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | carballo
# Processing Record 45 of Set 2 | chengde
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | teknaf
# Processing Record 48 of Set 2 | derzhavinsk
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | lata
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | nara
# Processing Record 4 of Set 3 | okato
# Processing Record 5 of Set 3 | zig
# Processing Record 6 of Set 3 | progreso
# Processing Record 7 of Set 3 | urumqi
# City not found. Skipping...
# Processing Record 8 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 3 | deniliquin
# Processing Record 11 of Set 3 | watsa
# Processing Record 12 of Set 3 | matay
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | mushie
# Processing Record 16 of Set 3 | zhezkazgan
# Processing Record 17 of Set 3 | maceio
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | lithakia
# Processing Record 20 of Set 3 | lang son
# Processing Record 21 of Set 3 | avera
# Processing Record 22 of Set 3 | sur
# Processing Record 23 of Set 3 | severodvinsk
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | bluff
# Processing Record 27 of Set 3 | krasnyy klyuch
# Processing Record 28 of Set 3 | weihe
# Processing Record 29 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 3 | bouna
# Processing Record 31 of Set 3 | marsa matruh
# Processing Record 32 of Set 3 | wajir
# Processing Record 33 of Set 3 | tilichiki
# Processing Record 34 of Set 3 | barrow
# Processing Record 35 of Set 3 | port elizabeth
# Processing Record 36 of Set 3 | los llanos de aridane
# Processing Record 37 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | kotelnikovo
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | russell
# Processing Record 43 of Set 3 | mnogovershinnyy
# Processing Record 44 of Set 3 | kapaa
# Processing Record 45 of Set 3 | aanekoski
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | japura
# Processing Record 48 of Set 3 | clyde river
# Processing Record 49 of Set 3 | khatanga
# Processing Record 50 of Set 3 | volga
# Processing Record 1 of Set 4 | warrington
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | sayabec
# City not found. Skipping...
# Processing Record 5 of Set 4 | chunoyar
# Processing Record 6 of Set 4 | buala
# Processing Record 7 of Set 4 | beyneu
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | talas
# Processing Record 13 of Set 4 | yarmouth
# Processing Record 14 of Set 4 | san jose
# Processing Record 15 of Set 4 | port hardy
# Processing Record 16 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 17 of Set 4 | san patricio
# Processing Record 18 of Set 4 | kaeo
# Processing Record 19 of Set 4 | zhuhai
# Processing Record 20 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 21 of Set 4 | sao felix do xingu
# Processing Record 22 of Set 4 | tomatlan
# Processing Record 23 of Set 4 | aykhal
# Processing Record 24 of Set 4 | diamantina
# Processing Record 25 of Set 4 | klaksvik
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | nsanje
# Processing Record 28 of Set 4 | burica
# City not found. Skipping...
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | gazni
# City not found. Skipping...
# Processing Record 31 of Set 4 | baiyin
# Processing Record 32 of Set 4 | menongue
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | khandbari
# Processing Record 35 of Set 4 | nhulunbuy
# Processing Record 36 of Set 4 | oranjemund
# Processing Record 37 of Set 4 | dingle
# Processing Record 38 of Set 4 | kichera
# Processing Record 39 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 40 of Set 4 | dunedin
# Processing Record 41 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 4 | pantai remis
# Processing Record 43 of Set 4 | ponta delgada
# Processing Record 44 of Set 4 | necochea
# Processing Record 45 of Set 4 | dikson
# Processing Record 46 of Set 4 | dunkirk
# Processing Record 47 of Set 4 | ixtapa
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | beringovskiy
# Processing Record 1 of Set 5 | cockburn town
# Processing Record 2 of Set 5 | arkhangelskoye
# Processing Record 3 of Set 5 | osmanabad
# Processing Record 4 of Set 5 | acapulco
# Processing Record 5 of Set 5 | coron
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | grand gaube
# Processing Record 8 of Set 5 | muros
# Processing Record 9 of Set 5 | miedzychod
# Processing Record 10 of Set 5 | flinders
# Processing Record 11 of Set 5 | bokoro
# City not found. Skipping...
# Processing Record 12 of Set 5 | le vauclin
# Processing Record 13 of Set 5 | tadine
# Processing Record 14 of Set 5 | tekeli
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | husavik
# Processing Record 17 of Set 5 | wicklow
# Processing Record 18 of Set 5 | ahipara
# Processing Record 19 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 20 of Set 5 | kurilsk
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | kommunisticheskiy
# Processing Record 23 of Set 5 | anloga
# Processing Record 24 of Set 5 | sergeyevka
# Processing Record 25 of Set 5 | parang
# Processing Record 26 of Set 5 | kenai
# Processing Record 27 of Set 5 | vila
# Processing Record 28 of Set 5 | takoradi
# Processing Record 29 of Set 5 | aksu
# Processing Record 30 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 5 | yazd
# Processing Record 33 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 5 | muskegon
# Processing Record 35 of Set 5 | samoded
# Processing Record 36 of Set 5 | teya
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | kashi
# City not found. Skipping...
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | saskylakh
# Processing Record 41 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 5 | sukhobuzimskoye
# Processing Record 43 of Set 5 | aguimes
# Processing Record 44 of Set 5 | pemangkat
# City not found. Skipping...
# Processing Record 45 of Set 5 | tommot
# Processing Record 46 of Set 5 | college
# Processing Record 47 of Set 5 | imbituba
# Processing Record 48 of Set 5 | mmabatho
# Processing Record 49 of Set 5 | tura
# Processing Record 50 of Set 5 | mattru
# Processing Record 1 of Set 6 | kohlu
# Processing Record 2 of Set 6 | pivijay
# Processing Record 3 of Set 6 | sao joao da barra
# Processing Record 4 of Set 6 | coahuayana
# Processing Record 5 of Set 6 | chapais
# Processing Record 6 of Set 6 | abu zabad
# Processing Record 7 of Set 6 | saldanha
# Processing Record 8 of Set 6 | valle del guamuez
# Processing Record 9 of Set 6 | vilyuysk
# Processing Record 10 of Set 6 | ishinomaki
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | tromso
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | maridi
# City not found. Skipping...
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | tomigusuku
# Processing Record 17 of Set 6 | bilibino
# Processing Record 18 of Set 6 | kolobovo
# Processing Record 19 of Set 6 | dakar
# Processing Record 20 of Set 6 | tugulym
# Processing Record 21 of Set 6 | zhanaozen
# Processing Record 22 of Set 6 | satun
# Processing Record 23 of Set 6 | dordrecht
# Processing Record 24 of Set 6 | nago
# Processing Record 25 of Set 6 | fairbanks
# Processing Record 26 of Set 6 | mbini
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | redlands
# Processing Record 29 of Set 6 | the valley
# Processing Record 30 of Set 6 | byron bay
# Processing Record 31 of Set 6 | sao miguel do araguaia
# Processing Record 32 of Set 6 | zeerust
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | soyo
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | saint george
# Processing Record 37 of Set 6 | manuk mangkaw
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | plainfield
# Processing Record 40 of Set 6 | rawson
# Processing Record 41 of Set 6 | srednekolymsk
# Processing Record 42 of Set 6 | hualmay
# Processing Record 43 of Set 6 | salalah
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | volkhov
# Processing Record 46 of Set 6 | tongliao
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | haapiti
# Processing Record 49 of Set 6 | pinotepa nacional
# City not found. Skipping...
# Processing Record 50 of Set 6 | katsuura
# Processing Record 1 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 2 of Set 7 | durban
# Processing Record 3 of Set 7 | kraslava
# Processing Record 4 of Set 7 | taoudenni
# Processing Record 5 of Set 7 | punta de bombon
# Processing Record 6 of Set 7 | cabatuan
# Processing Record 7 of Set 7 | labytnangi
# Processing Record 8 of Set 7 | gurlan
# Processing Record 9 of Set 7 | mtwara
# Processing Record 10 of Set 7 | rundu
# Processing Record 11 of Set 7 | constitucion
# Processing Record 12 of Set 7 | zarubino
# Processing Record 13 of Set 7 | asau
# City not found. Skipping...
# Processing Record 14 of Set 7 | sinnamary
# Processing Record 15 of Set 7 | khani
# Processing Record 16 of Set 7 | nakhon sawan
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | sola
# Processing Record 20 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 7 | iquitos
# Processing Record 22 of Set 7 | paamiut
# Processing Record 23 of Set 7 | houma
# Processing Record 24 of Set 7 | harper
# Processing Record 25 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 7 | tabuk
# Processing Record 27 of Set 7 | haines junction
# Processing Record 28 of Set 7 | awash
# Processing Record 29 of Set 7 | khandyga
# Processing Record 30 of Set 7 | la crosse
# Processing Record 31 of Set 7 | garissa
# Processing Record 32 of Set 7 | balkhash
# Processing Record 33 of Set 7 | mogadishu
# Processing Record 34 of Set 7 | zabol
# Processing Record 35 of Set 7 | inhambane
# Processing Record 36 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 37 of Set 7 | paranapanema
# Processing Record 38 of Set 7 | santo domingo
# Processing Record 39 of Set 7 | novo aripuana
# Processing Record 40 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 7 | cervo
# Processing Record 42 of Set 7 | khasan
# Processing Record 43 of Set 7 | manta
# Processing Record 44 of Set 7 | luanda
# Processing Record 45 of Set 7 | mount gambier
# Processing Record 46 of Set 7 | matamoros
# Processing Record 47 of Set 7 | orangeburg
# Processing Record 48 of Set 7 | baneh
# Processing Record 49 of Set 7 | nortelandia
# Processing Record 50 of Set 7 | talnakh
# Processing Record 1 of Set 8 | lianran
# Processing Record 2 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | wakkanai
# Processing Record 4 of Set 8 | karpogory
# Processing Record 5 of Set 8 | viedma
# Processing Record 6 of Set 8 | narsaq
# Processing Record 7 of Set 8 | krasnooktyabrskiy
# Processing Record 8 of Set 8 | chernyshevskiy
# Processing Record 9 of Set 8 | tabriz
# Processing Record 10 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 8 | lingyuan
# Processing Record 12 of Set 8 | southbridge
# Processing Record 13 of Set 8 | rosarito
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | myaundzha
# Processing Record 16 of Set 8 | tiksi
# Processing Record 17 of Set 8 | ankpa
# Processing Record 18 of Set 8 | potsdam
# Processing Record 19 of Set 8 | pevek
# Processing Record 20 of Set 8 | tezu
# Processing Record 21 of Set 8 | agua dulce
# Processing Record 22 of Set 8 | muravlenko
# Processing Record 23 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 8 | valparaiso
# Processing Record 25 of Set 8 | verkhoyansk
# Processing Record 26 of Set 8 | amahai
# Processing Record 27 of Set 8 | mareeba
# Processing Record 28 of Set 8 | sulangan
# Processing Record 29 of Set 8 | sucua
# Processing Record 30 of Set 8 | la asuncion
# Processing Record 31 of Set 8 | sabha
# Processing Record 32 of Set 8 | boddam
# Processing Record 33 of Set 8 | nantucket
# Processing Record 34 of Set 8 | luderitz
# Processing Record 35 of Set 8 | kajaani
# Processing Record 36 of Set 8 | pangody
# Processing Record 37 of Set 8 | sungaipenuh
# Processing Record 38 of Set 8 | champagnole
# Processing Record 39 of Set 8 | tocopilla
# Processing Record 40 of Set 8 | adrar
# Processing Record 41 of Set 8 | ormond beach
# Processing Record 42 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 8 | malindi
# Processing Record 44 of Set 8 | alta floresta
# Processing Record 45 of Set 8 | zwedru
# Processing Record 46 of Set 8 | kaitangata
# Processing Record 47 of Set 8 | vila franca do campo
# Processing Record 48 of Set 8 | saint anthony
# Processing Record 49 of Set 8 | morondava
# Processing Record 50 of Set 8 | nanortalik
# Processing Record 1 of Set 9 | north bend
# Processing Record 2 of Set 9 | peace river
# Processing Record 3 of Set 9 | dauriya
# Processing Record 4 of Set 9 | machaneng
# Processing Record 5 of Set 9 | berlevag
# Processing Record 6 of Set 9 | acarau
# City not found. Skipping...
# Processing Record 7 of Set 9 | saint-pierre
# Processing Record 8 of Set 9 | nouadhibou
# Processing Record 9 of Set 9 | naze
# Processing Record 10 of Set 9 | severo-kurilsk
# Processing Record 11 of Set 9 | halifax
# Processing Record 12 of Set 9 | vila velha
# Processing Record 13 of Set 9 | port shepstone
# Processing Record 14 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 15 of Set 9 | nioro
# Processing Record 16 of Set 9 | chicama
# Processing Record 17 of Set 9 | villa rica
# Processing Record 18 of Set 9 | mubi
# Processing Record 19 of Set 9 | taltal
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | yerbogachen
# Processing Record 22 of Set 9 | shieli
# Processing Record 23 of Set 9 | coos bay
# Processing Record 24 of Set 9 | texarkana
# Processing Record 25 of Set 9 | jacala
# Processing Record 26 of Set 9 | cruden bay
# City not found. Skipping...
# Processing Record 27 of Set 9 | richard toll
# City not found. Skipping...
# Processing Record 28 of Set 9 | rock sound
# Processing Record 29 of Set 9 | tateyama
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | kamaishi
# Processing Record 32 of Set 9 | sampit
# Processing Record 33 of Set 9 | comodoro rivadavia
# Processing Record 34 of Set 9 | guerrero negro
# Processing Record 35 of Set 9 | labuhan
# Processing Record 36 of Set 9 | mehamn
# Processing Record 37 of Set 9 | high level
# Processing Record 38 of Set 9 | denpasar
# Processing Record 39 of Set 9 | spencer
# Processing Record 40 of Set 9 | wamba
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | shenkursk
# Processing Record 43 of Set 9 | langxiang
# Processing Record 44 of Set 9 | hovd
# Processing Record 45 of Set 9 | vardo
# Processing Record 46 of Set 9 | wanaka
# Processing Record 47 of Set 9 | nanning
# Processing Record 48 of Set 9 | salihorsk
# Processing Record 49 of Set 9 | danielskuil
# Processing Record 50 of Set 9 | hailey
# Processing Record 1 of Set 10 | krasnodon
# Processing Record 2 of Set 10 | banda
# Processing Record 3 of Set 10 | pontianak
# Processing Record 4 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 10 | mackenzie
# Processing Record 6 of Set 10 | zyryanka
# Processing Record 7 of Set 10 | tenenkou
# Processing Record 8 of Set 10 | nuuk
# Processing Record 9 of Set 10 | cananeia
# Processing Record 10 of Set 10 | broken hill
# Processing Record 11 of Set 10 | seoul
# Processing Record 12 of Set 10 | nahrin
# Processing Record 13 of Set 10 | siloam springs
# Processing Record 14 of Set 10 | pathanamthitta
# Processing Record 15 of Set 10 | solnechnyy
# Processing Record 16 of Set 10 | ballitoville
# Processing Record 17 of Set 10 | bundaberg
# Processing Record 18 of Set 10 | yarada
# Processing Record 19 of Set 10 | murgab
# Processing Record 20 of Set 10 | kasamwa
# Processing Record 21 of Set 10 | cayenne
# Processing Record 22 of Set 10 | pindiga
# Processing Record 23 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 24 of Set 10 | puerto leguizamo
# Processing Record 25 of Set 10 | hofn
# Processing Record 26 of Set 10 | roma
# Processing Record 27 of Set 10 | pacifica
# Processing Record 28 of Set 10 | port blair
# Processing Record 29 of Set 10 | palembang
# Processing Record 30 of Set 10 | richards bay
# Processing Record 31 of Set 10 | bathsheba
# Processing Record 32 of Set 10 | gagnoa
# Processing Record 33 of Set 10 | jacksonville
# Processing Record 34 of Set 10 | meulaboh
# Processing Record 35 of Set 10 | antalaha
# Processing Record 36 of Set 10 | kitgum
# Processing Record 37 of Set 10 | lenger
# Processing Record 38 of Set 10 | peniche
# Processing Record 39 of Set 10 | moba
# Processing Record 40 of Set 10 | roebourne
# Processing Record 41 of Set 10 | arica
# Processing Record 42 of Set 10 | san julian
# Processing Record 43 of Set 10 | bowen
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | asfi
# City not found. Skipping...
# Processing Record 46 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 47 of Set 10 | leshukonskoye
# Processing Record 48 of Set 10 | bukoba
# Processing Record 49 of Set 10 | camacha
# Processing Record 50 of Set 10 | la jigua
# Processing Record 1 of Set 11 | burnie
# Processing Record 2 of Set 11 | oistins
# Processing Record 3 of Set 11 | qui nhon
# City not found. Skipping...
# Processing Record 4 of Set 11 | ocampo
# Processing Record 5 of Set 11 | shimoda
# Processing Record 6 of Set 11 | leirvik
# Processing Record 7 of Set 11 | verkhnyaya inta
# Processing Record 8 of Set 11 | te anau
# Processing Record 9 of Set 11 | ovre ardal
# Processing Record 10 of Set 11 | kutum
# Processing Record 11 of Set 11 | lazarev
# Processing Record 12 of Set 11 | hvide sande
# Processing Record 13 of Set 11 | linxia
# Processing Record 14 of Set 11 | saiha
# Processing Record 15 of Set 11 | port hedland
# Processing Record 16 of Set 11 | sinj
# Processing Record 17 of Set 11 | namibe
# Processing Record 18 of Set 11 | princeton
# Processing Record 19 of Set 11 | moussoro
# Processing Record 20 of Set 11 | tabou
# Processing Record 21 of Set 11 | timra
# Processing Record 22 of Set 11 | chilakalurupet
# Processing Record 23 of Set 11 | yulara
# Processing Record 24 of Set 11 | muisne
# Processing Record 25 of Set 11 | rutland
# Processing Record 26 of Set 11 | saraland
# Processing Record 27 of Set 11 | maragogi
# Processing Record 28 of Set 11 | strelka
# Processing Record 29 of Set 11 | kismayo
# City not found. Skipping...
# Processing Record 30 of Set 11 | dondo
# Processing Record 31 of Set 11 | mildura
# Processing Record 32 of Set 11 | pisco
# Processing Record 33 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 34 of Set 11 | tupik
# Processing Record 35 of Set 11 | urmary
# Processing Record 36 of Set 11 | kaputa
# Processing Record 37 of Set 11 | turkistan
# City not found. Skipping...
# Processing Record 38 of Set 11 | poum
# Processing Record 39 of Set 11 | bilma
# Processing Record 40 of Set 11 | divnomorskoye
# Processing Record 41 of Set 11 | jimma
# Processing Record 42 of Set 11 | boueni
# Processing Record 43 of Set 11 | half moon bay
# Processing Record 44 of Set 11 | mangrol
# Processing Record 45 of Set 11 | adiake
# Processing Record 46 of Set 11 | hemnesberget
# Processing Record 47 of Set 11 | ketchikan
# Processing Record 48 of Set 11 | toora-khem
# Processing Record 49 of Set 11 | pangnirtung
# Processing Record 50 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 12 | mahibadhoo
# Processing Record 2 of Set 12 | bang saphan
# Processing Record 3 of Set 12 | ercis
# Processing Record 4 of Set 12 | pitimbu
# Processing Record 5 of Set 12 | lethem
# Processing Record 6 of Set 12 | quatre cocos
# Processing Record 7 of Set 12 | kisaran
# Processing Record 8 of Set 12 | geraldton
# Processing Record 9 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 12 | upernavik
# Processing Record 11 of Set 12 | ekuvukeni
# Processing Record 12 of Set 12 | faya
# Processing Record 13 of Set 12 | timbiqui
# Processing Record 14 of Set 12 | mizdah
# Processing Record 15 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 16 of Set 12 | la ronge
# Processing Record 17 of Set 12 | catuday
# Processing Record 18 of Set 12 | hobyo
# Processing Record 19 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 12 | morristown
# Processing Record 21 of Set 12 | kampong cham
# Processing Record 22 of Set 12 | lewisporte
# Processing Record 23 of Set 12 | petauke
# Processing Record 24 of Set 12 | boden
# Processing Record 25 of Set 12 | eureka
# Processing Record 26 of Set 12 | moree
# Processing Record 27 of Set 12 | rome
# Processing Record 28 of Set 12 | tarko-sale
# Processing Record 29 of Set 12 | norman wells
# Processing Record 30 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 12 | general pico
# Processing Record 32 of Set 12 | yeppoon
# Processing Record 33 of Set 12 | wagga wagga
# Processing Record 34 of Set 12 | havoysund
# Processing Record 35 of Set 12 | teshie
# Processing Record 36 of Set 12 | nalut
# Processing Record 37 of Set 12 | sorong
# Processing Record 38 of Set 12 | vostok
# Processing Record 39 of Set 12 | axim
# Processing Record 40 of Set 12 | bubaque
# Processing Record 41 of Set 12 | kaihua
# Processing Record 42 of Set 12 | ialibu
# Processing Record 43 of Set 12 | key west
# Processing Record 44 of Set 12 | carlyle
# Processing Record 45 of Set 12 | baker city
# Processing Record 46 of Set 12 | senanga
# Processing Record 47 of Set 12 | mayo
# Processing Record 48 of Set 12 | ushtobe
# Processing Record 49 of Set 12 | borogontsy
# Processing Record 50 of Set 12 | calama
# Processing Record 1 of Set 13 | goderich
# Processing Record 2 of Set 13 | forio
# Processing Record 3 of Set 13 | mazagao
# Processing Record 4 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 5 of Set 13 | caravelas
# Processing Record 6 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 7 of Set 13 | kuruman
# Processing Record 8 of Set 13 | tiarei
# Processing Record 9 of Set 13 | domoni
# City not found. Skipping...
# Processing Record 10 of Set 13 | maumere
# Processing Record 11 of Set 13 | gondal
# Processing Record 12 of Set 13 | siverek
# Processing Record 13 of Set 13 | eastbourne
# Processing Record 14 of Set 13 | keetmanshoop
# Processing Record 15 of Set 13 | panguna
# Processing Record 16 of Set 13 | wanning
# Processing Record 17 of Set 13 | camacupa
# Processing Record 18 of Set 13 | north battleford
# Processing Record 19 of Set 13 | bud
# Processing Record 20 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 21 of Set 13 | balykshi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 553

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Punta Arenas -53.16  -70.91     48.20        66         100        6.93
# 1         Padang  -0.92  100.36     65.68        96         100        1.39
# 2           Chuy -33.69  -53.46     65.05        78           2       13.13
# 3  Mar Del Plata -46.43  -67.52     53.80        65           0       14.79
# 4        Qaanaaq  77.48  -69.36     -2.37        35           0        4.88
#
#   Country  Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0      CL                       0.0                       0.0
# 1      ID                       0.0                       0.0
# 2      UY                       0.0                       0.0
# 3      AR                       0.0                       0.0
# 4      GL                       0.0                       0.0

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Rain inches (last 3 hrs)","Snow inches (last 3 hrs)"]

# %%
city_data_df= city_data_df[new_column_order] 
city_data_df.head()
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.16  -70.91     48.20        66         100
# 1         Padang      ID  -0.92  100.36     65.68        96         100
# 2           Chuy      UY -33.69  -53.46     65.05        78           2
# 3  Mar Del Plata      AR -46.43  -67.52     53.80        65           0
# 4        Qaanaaq      GL  77.48  -69.36     -2.37        35           0
#
#    Wind Speed  Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0        6.93                       0.0                       0.0
# 1        1.39                       0.0                       0.0
# 2       13.13                       0.0                       0.0
# 3       14.79                       0.0                       0.0
# 4        4.88                       0.0                       0.0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
print("How many cities have recorded rainfall or snow?",len(city_data))
# Out:
# How many cities have recorded rainfall or snow? 553
